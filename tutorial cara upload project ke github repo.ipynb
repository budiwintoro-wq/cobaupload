# %% [markdown]
# # upload project ke github pakai vs code

# %% [markdown]
# mauk ke [github.com](https://github.com/) dan klik '**Create Repository**'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# buat repository baru

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# buka project yg ingin diupload di vs code
# jalankan perintah berikut di terminal
#
# > 'git init'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# jika menemukan error seperti ini![image.png](data:image/png;base64,...)

# %% [markdown]
# pastikan lagi kamu sudah install git dari sini : https://git-scm.com/install/
# jangan lupa restart vs code untuk memastikan instalasi git berhasil

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# jalankan kembali perintah
#
#
#
# ```
# # git init
# ```
#
# di terminal pada projek anda

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# oke sampai saat ini proses inisialisais berhasil

# %% [markdown]
# jalankan perintah
#
#
#
# ```
# # git add .
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# jalankan
#
#
#
# ```
# # git commit -am "initial commit"
# ```
#
# jika blm menghubungkan vs code ke github , silahkan lakukan login dl

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ekarang copy url repository anda dari github
#
# lalu jalankan perintah ini
#
#
#
# ```
# # git remote add origin 'linkrepoanda.git'
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# lalu cek
#
#
#
# ```
# # git remote -v
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
